# %% [markdown]
# # Harish Practise: Hierarchical Clustering

# %% [markdown]
#  Problem Statement: Using Hierarchical clustering for customer segmentation. We will cluster people based on their income and age.

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_excel("income.xlsx", names=["name","age","income"])
df
# Out:
#       name  age  income
# 0      Rob   29      45
# 1   Andrea   50      80
# 2    Mohan   35      52
# 3  Michael   32      41
# 4     Kory   36      87
# 5    David   48      68
# 6   Ismail   31      80
# 7   Sheela   55      60

# %%
sns.scatterplot(df, x="age",y="income",s=200)
plt.show()

# %% [markdown]
# ### Form clusters using sklearn AgglomerativeClustering

# %%
from sklearn.cluster import AgglomerativeClustering

X = df[["age", "income"]]
hc = AgglomerativeClustering(n_clusters=2, metric='euclidean',linkage='average')

hc.fit(X)
# Out:
# AgglomerativeClustering(linkage='average')

# %%
hc.labels_
# Out:
# array([1, 0, 1, 1, 0, 0, 0, 0], dtype=int64)

# %%
df["cluster"] = hc.labels_
df
# Out:
#       name  age  income  cluster
# 0      Rob   29      45        1
# 1   Andrea   50      80        0
# 2    Mohan   35      52        1
# 3  Michael   32      41        1
# 4     Kory   36      87        0
# 5    David   48      68        0
# 6   Ismail   31      80        0
# 7   Sheela   55      60        0

# %%
sns.scatterplot(df, x='age', y='income',  palette='viridis', s=100, hue="cluster")
plt.show()

# %% [markdown]
# ### Form clusters using scipy

# %%
from scipy.cluster.hierarchy import dendrogram, linkage, fcluster

X = df[['age', 'income']]
Z = linkage(X, method='average')
Z
# Out:
# array([[ 0.        ,  3.        ,  5.        ,  2.        ],
#        [ 4.        ,  6.        ,  8.60232527,  2.        ],
#        [ 2.        ,  8.        , 10.31064935,  3.        ],
#        [ 5.        ,  7.        , 10.63014581,  2.        ],
#        [ 1.        , 11.        , 16.39052659,  3.        ],
#        [ 9.        , 12.        , 23.69824661,  5.        ],
#        [10.        , 13.        , 33.65863823,  8.        ]])

# %% [markdown]
# Each row in the matrix above is for each merge operation. Total there were 7 merge operations. Each column represents,
# 1. First and Second column: Index of two rows (clusters) being merged
# 1. Third column: Distance between merged clusters
# 1. Forth column: Total number of data points in the cluster

# %%
np.sqrt((29-32)**2+(45-41)**2)
# Out:
# 5.0

# %%
# Plotting the dendrogram
plt.figure(figsize=(8,6))
plt.title('Hierarchical Clustering Dendrogram')
dendrogram(Z, labels=df['name'].values, leaf_rotation=90, leaf_font_size=10)
plt.xlabel('Sample index')
plt.ylabel('Distance')
plt.grid()
plt.show()

# %%
clusters = fcluster(Z, t=3, criterion="maxclust")
clusters
# Out:
# array([1, 3, 1, 1, 2, 3, 2, 3], dtype=int32)

# %%
df["cluster"] = clusters
df
# Out:
#       name  age  income  cluster
# 0      Rob   29      45        1
# 1   Andrea   50      80        3
# 2    Mohan   35      52        1
# 3  Michael   32      41        1
# 4     Kory   36      87        2
# 5    David   48      68        3
# 6   Ismail   31      80        2
# 7   Sheela   55      60        3

# %%
sns.scatterplot(df, x='age', y='income',  palette='viridis', s=100, hue="cluster")
plt.show()
